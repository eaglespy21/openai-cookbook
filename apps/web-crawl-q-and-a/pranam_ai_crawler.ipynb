# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os

# Regex pattern to match a URL
HTTP_URL_PATTERN = r'^http[s]*://.+'

# Define root domain to crawl
domain = "india.gov.in"
full_url = "https://www.india.gov.in/"

# Create a class to parse the HTML and get the hyperlinks
class HyperlinkParser(HTMLParser):
    def __init__(self):
        super().__init__()
        # Create a list to store the hyperlinks
        self.hyperlinks = []

    # Override the HTMLParser's handle_starttag method to get the hyperlinks
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)

        # If the tag is an anchor tag and it has an href attribute, add the href attribute to the list of hyperlinks
        if tag == "a" and "href" in attrs:
            self.hyperlinks.append(attrs["href"])

# Function to get the hyperlinks from a URL
def get_hyperlinks(url):
    
    # Try to open the URL and read the HTML
    try:
        # Open the URL and read the HTML
        with urllib.request.urlopen(url) as response:

            # If the response is not HTML, return an empty list
            if not response.info().get('Content-Type').startswith("text/html"):
                return []
            
            # Decode the HTML
            html = response.read().decode('utf-8')
    except Exception as e:
        print(e)
        return []

    # Create the HTML Parser and then Parse the HTML to get hyperlinks
    parser = HyperlinkParser()
    parser.feed(html)

    return parser.hyperlinks

# Function to get the hyperlinks from a URL that are within the same domain
def get_domain_hyperlinks(local_domain, url):
    clean_links = []
    for link in set(get_hyperlinks(url)):
        clean_link = None

        # If the link is a URL, check if it is within the same domain
        if re.search(HTTP_URL_PATTERN, link):
            # Parse the URL and check if the domain is the same
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain:
                clean_link = link

        # If the link is not a URL, check if it is a relative link
        else:
            if link.startswith("/"):
                link = link[1:]
            elif link.startswith("#") or link.startswith("mailto:"):
                continue
            clean_link = "https://" + local_domain + "/" + link

        if clean_link is not None:
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            clean_links.append(clean_link)

    # Return the list of hyperlinks that are within the same domain
    return list(set(clean_links))


def crawl(url):
    # Parse the URL and get the domain
    local_domain = urlparse(url).netloc

    # Create a queue to store the URLs to crawl
    queue = deque([url])

    # Create a set to store the URLs that have already been seen (no duplicates)
    seen = set([url])

    # Create a directory to store the text files
    if not os.path.exists("text/"):
            os.mkdir("text/")

    if not os.path.exists("text/"+local_domain+"/"):
            os.mkdir("text/" + local_domain + "/")

    # Create a directory to store the csv files
    if not os.path.exists("processed"):
            os.mkdir("processed")

    # While the queue is not empty, continue crawling
    while queue:

        # Get the next URL from the queue
        url = queue.pop()
        print(url) # for debugging and to see the progress
        print(len(queue))
        # Save text from the url to a <url>.txt file
        with open('text/'+local_domain+'/'+url[8:].replace("/", "_").replace("?", "_").replace("\\", "_") + ".txt", "w", encoding='utf-8') as f:

            # Get the text from the URL using BeautifulSoup
            soup = BeautifulSoup(requests.get(url).text, "html.parser")

            # Get the text but remove the tags
            text = soup.get_text()

            # If the crawler gets to a page that requires JavaScript, it will stop the crawl
            if ("You need to enable JavaScript to run this app." in text):
                print("Unable to parse page " + url + " due to JavaScript being required")
            
            # Otherwise, write the text to the file in the text directory
            f.write(text)

        # Get the hyperlinks from the URL and add them to the queue
        for link in get_domain_hyperlinks(local_domain, url):
            if link not in seen:
                queue.append(link)
                seen.add(link)

crawl(full_url)
# Out:
# https://www.india.gov.in/
# 0
# https://www.india.gov.in/topics/education
# 92
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls
# 118
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=5
# 127
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=4
# 126
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=3
# 125
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/javascript: void(0);
# 124
# URL can't contain control characters. '/javascript: void(0);' (found at least ' ')
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=1
# 123
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=85
# 122
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=2
# 121
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=7
# 120
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=6
# 119
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=10
# 120
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=9
# 119
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/apply-incentives-under-national-stimulus-plan-secondary-education-girls?page=8
# 118
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/scheme-provide-state-run-stipend-and-scholarship-cost-ration-tripura
# 117
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu
# 116
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=1
# 124
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=3
# 123
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=8
# 122
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=9
# 123
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=10
# 122
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=4
# 121
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=2
# 120
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=11
# 119
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=5
# 118
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=7
# 117
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-department-school-education-tamil-nadu?page=6
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-school-education-and-sports-department-maharashtra
# 115
# https://www.india.gov.in/official-website-central-institute-plastics-engineering-and-technology
# 114
# https://www.india.gov.in/information-department-higher-education
# 113
# https://www.india.gov.in/topics/education/higher-education
# 112
# https://www.india.gov.in/topics/education/higher-education?page=1
# 120
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=2
# 119
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=7
# 118
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=6
# 117
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=5
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=3
# 115
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=24
# 114
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=8
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/higher-education?page=4
# 112
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education
# 111
# https://www.india.gov.in/topics/education/elementary-education?page=1
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education?page=4
# 115
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education?page=5
# 114
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education?page=6
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education?page=2
# 112
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/elementary-education?page=3
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/adult-education
# 110
# https://www.india.gov.in/topics/education/adult-education?page=1
# 110
# https://www.india.gov.in/information-department-school-education-and-literacy
# 109
# https://www.india.gov.in/information-department-school-education-and-literacy?page=1
# 109
# https://www.india.gov.in/scheme-state-run-scholarship-and-stipend-nursing-student-tripura
# 108
# https://www.india.gov.in/information-polytechnic-colleges-andhra-pradesh
# 107
# https://www.india.gov.in/official-website-ministry-human-resource-development-0
# 106
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=85
# 114
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=4
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=2
# 112
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=5
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=6
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=8
# 109
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=1
# 108
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=7
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-human-resource-development-0?page=3
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/scheme-ardd-scholarship-and-stipend-internship-scholarship-tripura
# 105
# https://www.india.gov.in/information-about-council-architecture
# 104
# https://www.india.gov.in/information-about-council-architecture?page=5
# 112
# https://www.india.gov.in/information-about-council-architecture?page=9
# 112
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=2
# 111
# https://www.india.gov.in/information-about-council-architecture?page=1
# 110
# https://www.india.gov.in/information-about-council-architecture?page=31
# 109
# https://www.india.gov.in/information-about-council-architecture?page=27
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=29
# 115
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=25
# 114
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=26
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=24
# 112
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=23
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=28
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=30
# 109
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=8
# 108
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=7
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=6
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-about-council-architecture?page=4
# 105
# https://www.india.gov.in/information-about-council-architecture?page=3
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/scheme-provide-ardd-scholarship-and-stipend-stipend-tripura
# 103
# https://www.india.gov.in/acts-and-rules-department-school-education-tamil-nadu
# 102
# https://www.india.gov.in/website-minority-affairs-and-madrasah-education-department-west-bengal
# 101
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-schemes-students-madhya-pradesh
# 100
# https://www.india.gov.in/information-schemes-students-madhya-pradesh?page=1
# 100
# https://www.india.gov.in/topics/education?qt-relevant_links_in=2#qt-relevant_links_in
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/prime-ministers-scholarship-scheme-pmss
# 98
# https://www.india.gov.in/online-textbooks-national-council-educational-research-and-training
# 97
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education
# 96
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=8
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=3
# 103
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=64
# 102
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=2
# 101
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=1
# 100
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=7
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=6
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=5
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education/secondary-higher-secondary-education?page=4
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education?qt-relevant_links_in=1#qt-relevant_links_in
# 95
# https://www.india.gov.in/official-website-all-india-council-technical-education
# 94
# https://www.india.gov.in/distance-education-bureau-bureau-university-grants-commission
# 93
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/education?qt-relevant_links_in=0#qt-relevant_links_in
# 92
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/tell-friend
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit
# 90
# https://www.india.gov.in/india-glance/places-visit?page=4
# 99
# https://www.india.gov.in/india-glance/places-visit?page=8
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=3
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/modes-travel
# 96
# https://www.india.gov.in/india-glance/modes-travel?page=1
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=5
# 95
# https://www.india.gov.in/india-glance/places-visit?page=9
# 95
# https://www.india.gov.in/india-glance/places-visit?page=11
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=13
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=10
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=12
# 95
# https://www.india.gov.in/india-glance/places-visit?page=14
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=16
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=15
# 95
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=6
# 94
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=7
# 93
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=1
# 92
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=41
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/places-visit?page=2
# 90
# https://www.india.gov.in/topics/finance-taxes
# 89
# https://www.india.gov.in/find-information-about-your-area-tax-assessment-officer
# 117
# https://www.india.gov.in/topics/finance-taxes/economy
# 116
# https://www.india.gov.in/topics/finance-taxes/economy?page=6
# 122
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=3
# 121
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=7
# 120
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=5
# 119
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=2
# 118
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=1
# 117
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/economy?page=4
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/credit-monitoring-cell-micro-small-and-medium-enterprises
# 115
# https://www.india.gov.in/credit-monitoring-cell-micro-small-and-medium-enterprises?page=2
# 116
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/credit-monitoring-cell-micro-small-and-medium-enterprises?page=1
# 115
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ujjawala-scheme-wcd-odisha-grant-aid-portal-odisha
# 114
# https://www.india.gov.in/topics/finance-taxes/banking
# 113
# https://www.india.gov.in/topics/finance-taxes/banking?page=2
# 114
# https://www.india.gov.in/topics/finance-taxes/banking?page=1
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-business-portal
# 112
# https://www.india.gov.in/topics/finance-taxes?qt-relevant_links_in=2#qt-relevant_links_in
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-department-revenue
# 110
# https://www.india.gov.in/national-portal-credit-linked-government-schemes
# 109
# https://www.india.gov.in/national-portal-credit-linked-government-schemes?page=2
# 110
# https://www.india.gov.in/national-portal-credit-linked-government-schemes?page=1
# 109
# https://www.india.gov.in/official-website-allahabad-bank
# 108
# https://www.india.gov.in/information-tax-holiday-scheme-micro-small-medium-enterprises-development-commissioner
# 107
# https://www.india.gov.in/access-report-7th-central-pay-commission
# 106
# https://www.india.gov.in/topics/finance-taxes/pension
# 105
# https://www.india.gov.in/topics/finance-taxes/pension?page=1
# 107
# https://www.india.gov.in/topics/finance-taxes/pension?page=3
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/pension?page=2
# 105
# https://www.india.gov.in/official-website-ministry-finance-0
# 104
# https://www.india.gov.in/official-website-ministry-finance-0?page=1
# 105
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-finance-0?page=2
# 104
# https://www.india.gov.in/topics/finance-taxes/trade
# 103
# https://www.india.gov.in/topics/finance-taxes/trade?page=2
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/trade?page=1
# 103
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-department-investment-and-public-asset-management
# 102
# https://www.india.gov.in/website-e-manadeya-scheme-odisha
# 101
# https://www.india.gov.in/information-foreign-trade
# 100
# https://www.india.gov.in/tamil-nadu-tender-transparency-act-and-rules
# 99
# https://www.india.gov.in/official-website-department-financial-services
# 98
# https://www.india.gov.in/official-website-department-financial-services?page=1
# 98
# https://www.india.gov.in/information-department-economic-affairs
# 97
# https://www.india.gov.in/topics/finance-taxes/insurance
# 96
# https://www.india.gov.in/topics/finance-taxes/insurance?page=1
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/telephone-directory-jharkhand-commercial-tax-department
# 95
# https://www.india.gov.in/scheme-stand-india-business-activity-loan
# 94
# https://www.india.gov.in/scheme-stand-india-business-activity-loan?page=1
# 94
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes?qt-relevant_links_in=0#qt-relevant_links_in
# 93
# https://www.india.gov.in/topics/finance-taxes?qt-relevant_links_in=1#qt-relevant_links_in
# 92
# https://www.india.gov.in/topics/finance-taxes/taxes
# 91
# https://www.india.gov.in/topics/finance-taxes/taxes?page=7
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/taxes?page=6
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/taxes?page=4
# 95
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/taxes?page=1
# 94
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/finance-taxes/taxes?page=5
# 93
# https://www.india.gov.in/topics/finance-taxes/taxes?page=2
# 92
# https://www.india.gov.in/topics/finance-taxes/taxes?page=3
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/track-status-importer-and-exporter-registration-code
# 90
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/student-credit-card-scheme-department-higher-education-west-bengal
# 89
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/scheduled-tribes-and-other-traditional-forest-dwellers
# 88
# https://www.india.gov.in
# 87
# https://www.india.gov.in/topics/rural
# 86
# https://www.india.gov.in/website-national-social-assistance-programme-nsap-0
# 111
# https://www.india.gov.in/website-national-social-assistance-programme-nsap-0?page=1
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-kalia-krushak-assistance-livelihood-and-income-augmentation-scheme-odisha
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/pension-payment-details-nsap-beneficiaries
# 109
# https://www.india.gov.in/monitoring-reports-under-social-assistance-nsap
# 108
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/summary-report-gram-panchayats-saanjhi-phase-i-and-phase-ii-under-saansad-adarsh-gram-yojana-sagy
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/sanctioned-nsap-beneficiaries-old-aged-disability-and-widows-scheme-nsap-mis
# 106
# https://www.india.gov.in/watershed-guidelines-department-land-resources
# 105
# https://www.india.gov.in/assam-public-health-engineering-department
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/online-accounting-software-panchayati-raj-institutions
# 103
# https://www.india.gov.in/online-accounting-software-panchayati-raj-institutions?page=1
# 103
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural?qt-relevant_links_in=2#qt-relevant_links_in
# 102
# https://www.india.gov.in/rural-engineering-department-uttar-pradesh
# 101
# https://www.india.gov.in/policies-and-acts-ministry-rural-development
# 100
# https://www.india.gov.in/policies-and-acts-ministry-rural-development?page=1
# 100
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural/development
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/rural-employment-generation-programme
# 98
# https://www.india.gov.in/rural-employment-generation-programme?page=1
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/rural-employment-generation-programme?page=2
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/schemes-and-programmes-rural-development-department-himachal-pradesh
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/application-tracker-nsap-mis
# 96
# https://www.india.gov.in/official-website-department-land-resources-0
# 95
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural?qt-relevant_links_in=1#qt-relevant_links_in
# 94
# https://www.india.gov.in/topics/rural?qt-relevant_links_in=0#qt-relevant_links_in
# 93
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural/rural-employment
# 92
# https://www.india.gov.in/topics/rural/rural-employment?page=1
# 92
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-national-panchayat-awards
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-ministry-rural-development-0
# 90
# https://www.india.gov.in/official-website-ministry-rural-development-0?page=1
# 90
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/national-rural-livelihoods-mission-ministry-rural-development
# 89
# https://www.india.gov.in/national-rural-livelihoods-mission-ministry-rural-development?page=1
# 89
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-spatial-planning-gram-manchitra
# 88
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural/panchayati-raj
# 87
# https://www.india.gov.in/topics/rural/panchayati-raj?page=2
# 90
# https://www.india.gov.in/topics/rural/panchayati-raj?page=4
# 89
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural/panchayati-raj?page=3
# 88
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/rural/panchayati-raj?page=1
# 87
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-acts-and-rules-department-land-resources
# 86
# https://www.india.gov.in/topics/communications-it
# 85
# https://www.india.gov.in/information-e-governance-development
# 109
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/telecom
# 108
# https://www.india.gov.in/topics/communications-it/telecom?page=5
# 113
# https://www.india.gov.in/topics/communications-it/telecom?page=6
# 112
# https://www.india.gov.in/topics/communications-it/telecom?page=4
# 111
# https://www.india.gov.in/topics/communications-it/telecom?page=1
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/telecom?page=2
# 109
# https://www.india.gov.in/topics/communications-it/telecom?page=3
# 108
# https://www.india.gov.in/topics/communications-it/electronics-it
# 107
# https://www.india.gov.in/topics/communications-it/electronics-it?page=14
# 115
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=3
# 114
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=8
# 113
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=4
# 112
# https://www.india.gov.in/topics/communications-it/electronics-it?page=6
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=7
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=2
# 109
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=5
# 108
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/electronics-it?page=1
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-universal-service-obligation-fund-usof
# 106
# https://www.india.gov.in/website-universal-service-obligation-fund-usof?page=2
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-universal-service-obligation-fund-usof?page=1
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-himachal-pradesh-postal-circle
# 105
# https://www.india.gov.in/digital-india-internship-scheme
# 104
# https://www.india.gov.in/digital-india-internship-scheme?page=5
# 112
# https://www.india.gov.in/digital-india-internship-scheme?page=9
# 111
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=6
# 110
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=1
# 109
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=4
# 108
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=3
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=2
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=8
# 105
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/digital-india-internship-scheme?page=7
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-assam-postal-circle
# 103
# https://www.india.gov.in/official-website-standardisation-testing-and-quality-certification-directorate
# 102
# https://www.india.gov.in/topics/communications-it?qt-relevant_links_in=2#qt-relevant_links_in
# 101
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/application-form-payment-telephone-bills-through-electric-clearing-services-ecs-andhra-pradesh
# 100
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it
# 99
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=4
# 107
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=1
# 106
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=5
# 105
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=3
# 104
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=8
# 103
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=6
# 102
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=2
# 101
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=9
# 100
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/visvesvaraya-phd-scheme-electronics-it?page=7
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it?qt-relevant_links_in=0#qt-relevant_links_in
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-national-e-governance-plan
# 97
# https://www.india.gov.in/information-national-e-governance-plan?page=1
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/post
# 96
# https://www.india.gov.in/topics/communications-it/post?page=1
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it/post?page=2
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology
# 95
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=6
# 103
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=1
# 102
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=5
# 101
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=2
# 100
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=3
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=4
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=8
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=7
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/annual-reports-ministry-electronics-and-information-technology?page=9
# 95
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-postal-training-centre-mysore
# 94
# https://www.india.gov.in/manipur-state-information-technology-society
# 93
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states
# 92
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=8
# 100
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=6
# 99
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=2
# 98
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=5
# 97
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=9
# 96
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=7
# 95
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=3
# 94
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=4
# 93
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/guidelines-implementation-common-services-centers-csc-scheme-states?page=1
# 92
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-kerala-postal-circle
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-ministry-electronics-information-technology
# 90
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/international-cooperation-information-technology
# 89
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/communications-it?qt-relevant_links_in=1#qt-relevant_links_in
# 88
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-national-informatics-centre
# 87
# https://www.india.gov.in/organizations-department-electronics-and-information-technology
# 86
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=6
# 94
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=4
# 93
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=2
# 92
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=3
# 91
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=5
# 90
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=9
# 89
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=1
# 88
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=8
# 87
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/organizations-department-electronics-and-information-technology?page=7
# 86
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/multiplier-grants-scheme-ministry-electronics-information-technology
# 85
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament
# 84
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha
# 85
# https://www.india.gov.in/my-government/indian-parliament/rodmal-nagar
# 149
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/a?title=&field_state_name_value=
# 148
# https://www.india.gov.in/my-government/indian-parliament/ganeshamurthi
# 175
# https://www.india.gov.in/my-government/indian-parliament/aparajita-sarangi
# 174
# https://www.india.gov.in/my-government/indian-parliament/arvind-kumar-sharma
# 173
# https://www.india.gov.in/my-government/indian-parliament/ajay-teni-misra
# 172
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/asaduddin-owaisi
# 171
# https://www.india.gov.in/my-government/indian-parliament/akp-chinraj
# 170
# https://www.india.gov.in/my-government/indian-parliament/asit-kumar-mal
# 169
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/arun-sao
# 168
# https://www.india.gov.in/my-government/indian-parliament/anto-antony
# 167
# https://www.india.gov.in/my-government/indian-parliament/ajay-nishad
# 166
# https://www.india.gov.in/my-government/indian-parliament/ajay-kumar-mandal
# 165
# https://www.india.gov.in/my-government/indian-parliament/ajay-tamta
# 164
# https://www.india.gov.in/my-government/indian-parliament/arjun-singh
# 163
# https://www.india.gov.in/my-government/indian-parliament/adala-prabhakara-reddy
# 162
# https://www.india.gov.in/my-government/indian-parliament/achyutananda-samanta
# 161
# https://www.india.gov.in/my-government/indian-parliament/atul-kumar-singh
# 160
# https://www.india.gov.in/my-government/indian-parliament/anubhav-mohanty
# 159
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/amit-anil-chandra-shah
# 158
# https://www.india.gov.in/my-government/indian-parliament/anumula-revanth-reddy
# 157
# https://www.india.gov.in/my-government/indian-parliament/anurag-sharma
# 156
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/a?title=&field_state_name_value=&page=1
# 155
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/alok-kumar-suman
# 154
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/ashok-mahadeorao-nete
# 153
# https://www.india.gov.in/my-government/indian-parliament/afzal-ansari
# 152
# https://www.india.gov.in/my-government/indian-parliament/abu-taher-khan
# 151
# https://www.india.gov.in/my-government/indian-parliament/ajay-bhatt
# 150
# https://www.india.gov.in/my-government/indian-parliament/arun-kumar-sagar
# 149
# https://www.india.gov.in/my-government/indian-parliament/anil-firojiya
# 148
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/s?title=&field_state_name_value=
# 147
# https://www.india.gov.in/my-government/indian-parliament/shyam-singh-yadav
# 170
# https://www.india.gov.in/my-government/indian-parliament/simranjit-singh-mann
# 169
# https://www.india.gov.in/my-government/indian-parliament/satish-kumar-gautam
# 168
# https://www.india.gov.in/my-government/indian-parliament/sisir-kumar-adhikari
# 167
# https://www.india.gov.in/my-government/indian-parliament/ss-palanimanickam
# 166
# https://www.india.gov.in/my-government/indian-parliament/s-jagathrakshakan
# 165
# https://www.india.gov.in/my-government/indian-parliament/shatrughan-prasad-sinha
# 164
# https://www.india.gov.in/my-government/indian-parliament/s-jothi-mani
# 163
# https://www.india.gov.in/my-government/indian-parliament/sudip-bandyopadhyay
# 162
# https://www.india.gov.in/my-government/indian-parliament/sujay-radhakrishna-vikhepatil
# 161
# https://www.india.gov.in/my-government/indian-parliament/sudhakar-tukaram-shrangare
# 160
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/ss-ahluwalia
# 159
# https://www.india.gov.in/my-government/indian-parliament/sunil-kumar-singh
# 158
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/s?title=&field_state_name_value=&page=2
# 157
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/sanjay-sadashivrao-mandlik
# 156
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/s?title=&field_state_name_value=&page=1
# 155
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/sumedhanand-saraswati
# 154
# https://www.india.gov.in/my-government/indian-parliament/sangeeta-kumari-singh-deo
# 153
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/subhas-sarkar
# 152
# https://www.india.gov.in/my-government/indian-parliament/shashi-tharoor
# 151
# https://www.india.gov.in/my-government/indian-parliament/shrikant-eknath-shinde
# 150
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/s?title=&field_state_name_value=&page=3
# 149
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/smriti-zubin-irani
# 148
# https://www.india.gov.in/my-government/indian-parliament/sanjay-bhatia
# 147
# https://www.india.gov.in/my-government/indian-parliament/sakshi-ji-swami-maharaj
# 146
# https://www.india.gov.in/my-government/indian-parliament/kavitha-maloth
# 145
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/r?title=&field_state_name_value=
# 144
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/pragya-singh-thakur
# 143
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/g?title=&field_state_name_value=
# 142
# https://www.india.gov.in/my-government/indian-parliament/gurjeet-singh-aujla
# 167
# https://www.india.gov.in/my-government/indian-parliament/gautham-sigamani-pon
# 166
# https://www.india.gov.in/my-government/indian-parliament/gomati-sai
# 165
# https://www.india.gov.in/my-government/indian-parliament/geetha-viswanath-vanga
# 164
# https://www.india.gov.in/my-government/indian-parliament/goddeti-madhavi
# 163
# https://www.india.gov.in/my-government/indian-parliament/gyaneshwar-patil
# 162
# https://www.india.gov.in/my-government/indian-parliament/gowdar-mallikarjunappa-siddeshwara
# 161
# https://www.india.gov.in/my-government/indian-parliament/ganesan-selvam
# 160
# https://www.india.gov.in/my-government/indian-parliament/gitaben-vajesingbhai-rathva
# 159
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/guharam-ajgalley
# 158
# https://www.india.gov.in/my-government/indian-parliament/gajanan-chandrakant-kirtikar
# 157
# https://www.india.gov.in/my-government/indian-parliament/gautam-gambhir
# 156
# https://www.india.gov.in/my-government/indian-parliament/giriraj-singh
# 155
# https://www.india.gov.in/my-government/indian-parliament/girish-bhalchandra-bapat
# 154
# https://www.india.gov.in/my-government/indian-parliament/giridhari-yadav
# 153
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/gopal-chinayya-shetty
# 152
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/gaurav-gogoi
# 151
# https://www.india.gov.in/my-government/indian-parliament/gangasandra-siddappa-basavaraj
# 150
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/gaddam-ranjith-reddy
# 149
# https://www.india.gov.in/my-government/indian-parliament/ganesh-singh
# 148
# https://www.india.gov.in/my-government/indian-parliament/geeta-kora
# 147
# https://www.india.gov.in/my-government/indian-parliament/gajendra-singh-patel
# 146
# https://www.india.gov.in/my-government/indian-parliament/ghanshyam-singh-lodhi
# 145
# https://www.india.gov.in/my-government/indian-parliament/guman-singh-damor
# 144
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/girish-chandra
# 143
# https://www.india.gov.in/my-government/indian-parliament/gajendra-singh-shekhawat
# 142
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/o?title=&field_state_name_value=
# 141
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/l?title=&field_state_name_value=
# 140
# https://www.india.gov.in/my-government/indian-parliament/ls-tejasvi-surya
# 143
# https://www.india.gov.in/my-government/indian-parliament/lallu-singh
# 142
# https://www.india.gov.in/my-government/indian-parliament/lorho-s-pfoze
# 141
# https://www.india.gov.in/my-government/indian-parliament/lalubhai-babubhai-patel
# 140
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/k?title=&field_state_name_value=
# 139
# https://www.india.gov.in/my-government/indian-parliament/karti-p-chidambaram
# 167
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/k?title=&field_state_name_value=&page=1
# 166
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/kumbakudi-sudhakaran
# 165
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/kunar-hembram
# 164
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/kailash-choudhary
# 163
# https://www.india.gov.in/my-government/indian-parliament/k-jayakumar
# 162
# https://www.india.gov.in/my-government/indian-parliament/khalilur-rahaman
# 161
# https://www.india.gov.in/my-government/indian-parliament/kirti-vardhan-singh
# 160
# https://www.india.gov.in/my-government/indian-parliament/kanakmal-katara
# 159
# https://www.india.gov.in/my-government/indian-parliament/kanimozhi-karunanidhi
# 158
# https://www.india.gov.in/my-government/indian-parliament/kotha-prabhakar-reddy
# 157
# https://www.india.gov.in/my-government/indian-parliament/kavita-singh
# 156
# https://www.india.gov.in/my-government/indian-parliament/kapil-moreshwar-patil
# 155
# https://www.india.gov.in/my-government/indian-parliament/kalaben-mohanbhai-delkar
# 154
# https://www.india.gov.in/my-government/indian-parliament/kirit-premjibhai-solanki
# 153
# https://www.india.gov.in/my-government/indian-parliament/krishnapal-singh-yadav
# 152
# https://www.india.gov.in/my-government/indian-parliament/khagen-murmu
# 151
# https://www.india.gov.in/my-government/indian-parliament/krishan-pal-gurjar
# 150
# https://www.india.gov.in/my-government/indian-parliament/kinjarapu-ram-mohan-naidu
# 149
# https://www.india.gov.in/my-government/indian-parliament/krupal-balaji-tumane
# 148
# https://www.india.gov.in/my-government/indian-parliament/khan-saumitra
# 147
# https://www.india.gov.in/my-government/indian-parliament/kani-k-navas
# 146
# https://www.india.gov.in/my-government/indian-parliament/k-shanmuga-sundaram
# 145
# https://www.india.gov.in/my-government/indian-parliament/kalyan-banerjee
# 144
# https://www.india.gov.in/my-government/indian-parliament/kuldeep-rai-sharma
# 143
# https://www.india.gov.in/my-government/indian-parliament/kaushal-kishore
# 142
# https://www.india.gov.in/my-government/indian-parliament/k-muraleedharan
# 141
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/k-subbarayan
# 140
# https://www.india.gov.in/my-government/indian-parliament/komati-reddy-venkat-reddy
# 139
# https://www.india.gov.in/my-government/indian-parliament/mahesh-sahoo
# 138
# https://www.india.gov.in/my-government/indian-parliament/suresh-kumar-kashyap
# 137
# https://www.india.gov.in/my-government/indian-parliament/locket-chatterjee
# 136
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/p?title=&field_state_name_value=
# 135
# https://www.india.gov.in/my-government/indian-parliament/p-ravindhranath
# 161
# https://www.india.gov.in/my-government/indian-parliament/prahlad-singh-patel
# 160
# https://www.india.gov.in/my-government/indian-parliament/pradeep-kumar-singh
# 159
# https://www.india.gov.in/my-government/indian-parliament/p-velusamy
# 158
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/pr-natarajan
# 157
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/parvatagouda-chandanagouda-gaddigoudar
# 156
# https://www.india.gov.in/my-government/indian-parliament/prajwal-revanna
# 155
# https://www.india.gov.in/my-government/indian-parliament/parvesh-sahib-singh
# 154
# https://www.india.gov.in/my-government/indian-parliament/pashupati-nath-singh
# 153
# https://www.india.gov.in/my-government/indian-parliament/prasun-banerjee
# 152
# https://www.india.gov.in/my-government/indian-parliament/pp-chaudhary
# 151
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/p?title=&field_state_name_value=&page=1
# 150
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/pallab-lochan-das
# 149
# https://www.india.gov.in/my-government/indian-parliament/poonam-mahajan-vajendla-rao
# 148
# https://www.india.gov.in/my-government/indian-parliament/pramila-bisoyi
# 147
# https://www.india.gov.in/my-government/indian-parliament/prataprao-patil-chikhalikar
# 146
# https://www.india.gov.in/my-government/indian-parliament/pratibha-singh
# 145
# https://www.india.gov.in/my-government/indian-parliament/pakauri-lal
# 144
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/praveen-kumar-nishad
# 143
# https://www.india.gov.in/my-government/indian-parliament/p-c-mohan
# 142
# https://www.india.gov.in/my-government/indian-parliament/midhun-reddy
# 141
# https://www.india.gov.in/my-government/indian-parliament/prabhubhai-nagarbhai-vasava
# 140
# https://www.india.gov.in/my-government/indian-parliament/pratima-bhoumik
# 139
# https://www.india.gov.in/my-government/indian-parliament/pradyut-bordoloi
# 138
# https://www.india.gov.in/my-government/indian-parliament/pushpendra-singh-chandel
# 137
# https://www.india.gov.in/my-government/indian-parliament/pradeep-kumar-chaudhary
# 136
# https://www.india.gov.in/my-government/indian-parliament/pocha-brahmananda-reddy
# 135
# https://www.india.gov.in/my-government/indian-parliament/kotagiri-sridhar
# 134
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha?page=2
# 133
# https://www.india.gov.in/my-government/indian-parliament/malook-nagar
# 150
# https://www.india.gov.in/my-government/indian-parliament/shri-ramshiromani-verma
# 149
# https://www.india.gov.in/my-government/indian-parliament/mansukhbhai-dhanjibhai-vasava
# 148
# https://www.india.gov.in/my-government/indian-parliament/rajendra-agrawal
# 147
# https://www.india.gov.in/my-government/indian-parliament/abdussamad-samadani
# 146
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/rao-inderjit-singh
# 145
# https://www.india.gov.in/my-government/indian-parliament/bache-gowda-bn
# 144
# https://www.india.gov.in/my-government/indian-parliament/jaswantsinh-sumanbhai-bhabhor
# 143
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/chandra-sekhar-bellana
# 142
# https://www.india.gov.in/my-government/indian-parliament/francisco-cosme-sardinha
# 141
# https://www.india.gov.in/my-government/indian-parliament/hanuman-beniwal
# 140
# https://www.india.gov.in/my-government/indian-parliament/jayanta-kumar-roy
# 139
# https://www.india.gov.in/my-government/indian-parliament/dinesh-lal-nirahua-yadav
# 138
# https://www.india.gov.in/my-government/indian-parliament/dhal-singh-bisen
# 137
# https://www.india.gov.in/my-government/indian-parliament/mala-rajya-laxmi-shah
# 136
# https://www.india.gov.in/my-government/indian-parliament/jyotsna-charandas-mahant
# 135
# https://www.india.gov.in/my-government/indian-parliament/ranjan-singh-rajkumar
# 134
# https://www.india.gov.in/my-government/indian-parliament/bishweswar-tudu
# 133
# https://www.india.gov.in/my-government/indian-parliament/sunil-kumar-mondal
# 132
# https://www.india.gov.in/my-government/indian-parliament/ashok-kumar-yadav
# 131
# https://www.india.gov.in/my-government/indian-parliament/harsimrat-kaur-badal
# 130
# https://www.india.gov.in/my-government/indian-parliament/lok-sabha/b?title=&field_state_name_value=
# 129
# https://www.india.gov.in/my-government/indian-parliament/bharat-ram-margani
# 147
# https://www.india.gov.in/my-government/indian-parliament/bharatsinhji-shankarji-dabhi
# 146
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/indian-parliament/bhagwanth-khuba
# 145
# https://www.india.gov.in/my-government/indian-parliament/bhanu-pratap-singh-verma
# 144
# ...
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/government-directory/judiciary?page=4
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/government-directory/judiciary?page=5
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/government-directory/judiciary?page=2
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/home-affairs-enforcement/enforcement-organizations
# 73
# https://www.india.gov.in/topics/home-affairs-enforcement/enforcement-organizations?page=2
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/home-affairs-enforcement/enforcement-organizations?page=3
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/home-affairs-enforcement/enforcement-organizations?page=1
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/home-affairs-enforcement/enforcement-organizations?page=4
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/people-groups/community/businesspersons
# 72
# https://www.india.gov.in/people-groups/community/businesspersons?page=4
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/people-groups/community/businesspersons?page=3
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/people-groups/community/businesspersons?page=2
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/people-groups/community/businesspersons?page=1
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/people-groups/community/businesspersons?page=5
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/law-justice/law-commission-india
# 71
# https://www.india.gov.in/topics/defence/paramilitary-forces
# 70
# https://www.india.gov.in/topics/defence/paramilitary-forces?page=1
# 71
# https://www.india.gov.in/topics/defence/paramilitary-forces?page=2
# 70
# https://www.india.gov.in/people-groups/community/self-employed
# 69
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/demand-grant
# 68
# https://www.india.gov.in/my-government/documents/demand-grant?page=5
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/demand-grant?page=4
# 71
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/demand-grant?page=3
# 70
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/demand-grant?page=1
# 69
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/demand-grant?page=2
# 68
# https://www.india.gov.in/my-government/documents/annual-report
# 67
# https://www.india.gov.in/my-government/documents/annual-report?page=5
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=8
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=2
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=7
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=1
# 71
# https://www.india.gov.in/my-government/documents/annual-report?page=3
# 70
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=4
# 69
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=12
# 68
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/documents/annual-report?page=6
# 67
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/agriculture/dairy
# 66
# https://www.india.gov.in/topics/agriculture/dairy?page=2
# 67
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/agriculture/dairy?page=1
# 66
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/national-symbols
# 65
# https://www.india.gov.in/javascript:void(0);
# 64
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/india-glance/people-and-lifestyle
# 63
# https://www.india.gov.in/gsearch?s=Pan%20card
# 62
# https://www.india.gov.in/spotlight/union-budget-2023-2024
# 61
# https://www.india.gov.in/house-listing-and-housing-census-data-2011
# 60
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/my-government/whos-who/prime-minister
# 59
# https://www.india.gov.in/topics/labour-employment
# 58
# https://www.india.gov.in/information-new-age-craftsmen-training-scheme
# 79
# https://www.india.gov.in/information-new-age-craftsmen-training-scheme?page=4
# 82
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-new-age-craftsmen-training-scheme?page=3
# 81
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-new-age-craftsmen-training-scheme?page=2
# 80
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-new-age-craftsmen-training-scheme?page=1
# 79
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-employment-and-unemployment-survey-ministry-labour-and-employment
# 78
# https://www.india.gov.in/information-employment-and-unemployment-survey-ministry-labour-and-employment?page=1
# 80
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-employment-and-unemployment-survey-ministry-labour-and-employment?page=2
# 79
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-employment-and-unemployment-survey-ministry-labour-and-employment?page=3
# 78
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/form-pradhan-mantri-suraksha-bima-yojna
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advanced-vocational-training-scheme-avts
# 76
# https://www.india.gov.in/information-advanced-vocational-training-scheme-avts?page=1
# 79
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advanced-vocational-training-scheme-avts?page=4
# 78
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advanced-vocational-training-scheme-avts?page=2
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advanced-vocational-training-scheme-avts?page=3
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/cdac-recruitment-portal
# 75
# https://www.india.gov.in/official-website-labour-bureau-ministry-labour-and-employment
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/labour-employment?qt-relevant_links_in=1#qt-relevant_links_in
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-craftsmen-training-scheme-cts
# 72
# https://www.india.gov.in/information-craftsmen-training-scheme-cts?page=4
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-craftsmen-training-scheme-cts?page=3
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-craftsmen-training-scheme-cts?page=2
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-craftsmen-training-scheme-cts?page=1
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-employees-provident-fund-organisation
# 71
# https://www.india.gov.in/official-website-employees-provident-fund-organisation?page=1
# 71
# https://www.india.gov.in/website-ministry-labour-and-employment
# 70
# https://www.india.gov.in/website-ministry-labour-and-employment?page=1
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-ministry-labour-and-employment?page=2
# 71
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-ministry-labour-and-employment?page=3
# 70
# https://www.india.gov.in/information-employment-subsidy-scheme-directorate-industries-trade-and-commerce-goa
# 69
# https://www.india.gov.in/information-craftsmen-instructors-training-scheme-cits
# 68
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advance-diploma-national-skill-training-institute
# 67
# https://www.india.gov.in/information-advance-diploma-national-skill-training-institute?page=4
# 70
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advance-diploma-national-skill-training-institute?page=1
# 69
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advance-diploma-national-skill-training-institute?page=2
# 68
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-advance-diploma-national-skill-training-institute?page=3
# 67
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/official-website-directorate-general-factory-advice-service-and-labour-institute
# 66
# https://www.india.gov.in/website-punjab-skill-development-mission
# 65
# https://www.india.gov.in/topics/labour-employment?qt-relevant_links_in=2#qt-relevant_links_in
# 64
# https://www.india.gov.in/stub-50
# 64
# https://www.india.gov.in/information-employment-department-chandigarh
# 63
# https://www.india.gov.in/information-about-swavalamban-scheme
# 62
# https://www.india.gov.in/official-website-tripura-public-service-commission
# 61
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/labour-employment?qt-relevant_links_in=0#qt-relevant_links_in
# 60
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-directorate-general-employment-and-training
# 59
# https://www.india.gov.in/official-website-employment-news-weekly
# 58
# https://www.india.gov.in/topics/health-family-welfare
# 57
# https://www.india.gov.in/download-e-book-success-stories-health-sector
# 78
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/dr-ambedkar-medical-aid-scheme-haryana
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation
# 76
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=1
# 82
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=7
# 81
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=4
# 80
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=3
# 79
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=2
# 78
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=5
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/link-workers-scheme-operational-guidelines-national-aids-control-organisation?page=6
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-ayush-mark-certification-scheme
# 75
# https://www.india.gov.in/information-ayush-mark-certification-scheme?page=2
# 77
# https://www.india.gov.in/information-ayush-mark-certification-scheme?page=1
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/information-ayush-mark-certification-scheme?page=3
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/national-family-welfare-programme-department-health-and-family-welfare-punjab
# 74
# https://www.india.gov.in/health-training-institutes
# 73
# https://www.india.gov.in/health-training-institutes?page=13
# 81
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=4
# 80
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=6
# 79
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=1
# 78
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=7
# 77
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=2
# 76
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=8
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=3
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=5
# 73
# https://www.india.gov.in/health-training-institutes?page=9
# 73
# https://www.india.gov.in/health-training-institutes?page=10
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=11
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/health-training-institutes?page=12
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/website-ministry-health-family-welfare
# 72
# https://www.india.gov.in/topics/health-family-welfare?qt-relevant_links_in=1#qt-relevant_links_in
# 71
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/topics/health-family-welfare?qt-relevant_links_in=0#qt-relevant_links_in
# 70
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ministry-health-and-family-welfare-6
# 69
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=5
# 75
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=3
# 74
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=6
# 73
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=2
# 72
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=7
# 71
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=1
# 70
# https://www.india.gov.in/ministry-health-and-family-welfare-6?page=4
# 69
# HTTP Error 503: Service Unavailable
# https://www.india.gov.in/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%A7%E0%A4%BE%E0%A4%A8%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80-%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF-%E0%A4%B0%E0%A4%BE%E0%A4%B9%E0%A4%A4-%E0%A4%95%E0%A5%8B%E0%A4%B7-%E0%A4%95%E0%A5%87-%E0%A4%A4%E0%A4%B9%E0%A4%A4-%E0%A4%AA%E0%A5%88%E0%A4%A8%E0%A4%B2-%E0%A4%AE%E0%A5%87%E0%A4%82-%E0%A4%B6%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%B2-%E0%A4%A8%E0%A4%BF%E0%A4%9C%E0%A5%80-%E0%A4%85%E0%A4%B8%E0%A5%8D%E0%A4%AA%E0%A4%A4%E0%A4%BE%E0%A4%B2%E0%A5%8B%E0%A4%82-%E0%A4%95%E0%A5%80-%E0%A4%B8%E0%A5%82%E0%A4%9A%E0%A5%80
# 68
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 136
#     133                 queue.append(link)
#     134                 seen.add(link)
# --> 136 crawl(full_url)
#
# Cell In[1], line 115, in crawl(url)
#     113 print(len(queue))
#     114 # Save text from the url to a <url>.txt file
# --> 115 with open('text/'+local_domain+'/'+url[8:].replace("/", "_").replace("?", "_").replace("\\", "_") + ".txt", "w", encoding='utf-8') as f:
#     116
#     117     # Get the text from the URL using BeautifulSoup
#     118     soup = BeautifulSoup(requests.get(url).text, "html.parser")
#     120     # Get the text but remove the tags
#
# File c:\Projects\openai-cookbook\.venv310\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text/www.india.gov.in/www.india.gov.in_%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%A7%E0%A4%BE%E0%A4%A8%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80-%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF-%E0%A4%B0%E0%A4%BE%E0%A4%B9%E0%A4%A4-%E0%A4%95%E0%A5%8B%E0%A4%B7-%E0%A4%95%E0%A5%87-%E0%A4%A4%E0%A4%B9%E0%A4%A4-%E0%A4%AA%E0%A5%88%E0%A4%A8%E0%A4%B2-%E0%A4%AE%E0%A5%87%E0%A4%82-%E0%A4%B6%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%B2-%E0%A4%A8%E0%A4%BF%E0%A4%9C%E0%A5%80-%E0%A4%85%E0%A4%B8%E0%A5%8D%E0%A4%AA%E0%A4%A4%E0%A4%BE%E0%A4%B2%E0%A5%8B%E0%A4%82-%E0%A4%95%E0%A5%80-%E0%A4%B8%E0%A5%82%E0%A4%9A%E0%A5%80.txt'

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd

# Create a list to store the text files
texts=[]

#scraped_file_name
SCRAPED_FILENAME = 'scraped_'+domain+'.csv'
EMBEDDINGS_FILENAME = 'embeddings_'+domain+'.csv'

# Get all the text files in the text directory
for file in os.listdir("text/" + domain + "/"):

    # Open the file and read the text
    with open("text/" + domain + "/" + file, "r", encoding='utf-8') as f:
        text = f.read()

        # Omit the first 75 lines and the last 3 lines, then replace -, _, and #update with spaces.
        texts.append((file[75:-3].replace('-',' ').replace('_', ' ').replace('#update',''), text))

# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/' + SCRAPED_FILENAME)
df.head()

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv('processed/' + SCRAPED_FILENAME, index_col=0)
df.columns = ['title', 'text']

# Tokenize the text and save the number of tokens to a new column
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
max_tokens = 500

# Function to split the text into chunks of a maximum number of tokens
def split_into_many(text, max_tokens = max_tokens):

    # Split the text into sentences
    sentences = text.split('. ')

    # Get the number of tokens for each sentence
    n_tokens = [len(tokenizer.encode(" " + sentence)) for sentence in sentences]
    
    chunks = []
    tokens_so_far = 0
    chunk = []

    # Loop through the sentences and tokens joined together in a tuple
    for sentence, token in zip(sentences, n_tokens):

        # If the number of tokens so far plus the number of tokens in the current sentence is greater 
        # than the max number of tokens, then add the chunk to the list of chunks and reset
        # the chunk and tokens so far
        if tokens_so_far + token > max_tokens:
            chunks.append(". ".join(chunk) + ".")
            chunk = []
            tokens_so_far = 0

        # If the number of tokens in the current sentence is greater than the max number of 
        # tokens, go to the next sentence
        if token > max_tokens:
            continue

        # Otherwise, add the sentence to the chunk and add the number of tokens to the total
        chunk.append(sentence)
        tokens_so_far += token + 1

    return chunks
    

shortened = []

# Loop through the dataframe
for row in df.iterrows():

    # If the text is None, go to the next row
    if row[1]['text'] is None:
        continue

    # If the number of tokens is greater than the max number of tokens, split the text into chunks
    if row[1]['n_tokens'] > max_tokens:
        shortened += split_into_many(row[1]['text'])
    
    # Otherwise, add the text to the list of shortened texts
    else:
        shortened.append( row[1]['text'] )

# %%
df = pd.DataFrame(shortened, columns = ['text'])
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df.n_tokens.hist()
# Out:
# <AxesSubplot: >

# %%
import openai
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
) # for exponential backoff

@retry(wait=wait_random_exponential(min=1, max=120), stop=stop_after_attempt(20))
def embedding_with_backoff(**kwargs):
    return openai.Embedding.create(**kwargs)

openai.api_key_path='C:\Projects\openai-cookbook\openai_api_key.secret'
df['embeddings'] = df.text.apply(lambda x: embedding_with_backoff(input=x, engine='text-embedding-ada-002')['data'][0]['embedding'])
df.to_csv('processed/' + EMBEDDINGS_FILENAME)
df.head()
# Out:
#                                                 text  n_tokens  \
# 0  blog authors maddie.   Maddie Hall - OpenAI   ...       175
# 1  blog authors tom.   Tom Brown - OpenAI        ...       228
# 2  blog openai scholars 2019 final projects.   Op...       492
# 3  In this project, I used curiosity-driven explo...       478
# 4  Results revealed that the optimal RL policies ...       499
#
#                                           embeddings
# 0  [-0.012958061881363392, -0.006103983614593744,...
# 1  [-0.0053874170407652855, -0.009962032549083233...
# 2  [0.0019150723237544298, -0.0070442273281514645...
# 3  [-0.0067560747265815735, 0.0004431474662851542...
# 4  [-0.012868616729974747, 0.0029640409629791975,...

# %%
import pandas as pd
import numpy as np
from openai.embeddings_utils import distances_from_embeddings, cosine_similarity

df=pd.read_csv('processed/' + EMBEDDINGS_FILENAME, index_col=0)
df['embeddings'] = df['embeddings'].apply(eval).apply(np.array)

df.head()
# Out:
#                                                 text  n_tokens  \
# 0  .   OpenAI           Introducing ChatGPT resea...       149
# 1  .   OpenAI           Introducing ChatGPT resea...       149
# 2  about.   About OpenAI           Introducing Ch...       484
# 3  abs 2005.14165v1.   OpenAI     Introducing Cha...       153
# 4  abs 2005.14165v2.   OpenAI     Introducing Cha...       153
#
#                                           embeddings
# 0  [-0.008277355693280697, -0.012110493145883083,...
# 1  [-0.008277355693280697, -0.012110493145883083,...
# 2  [-0.005867346189916134, -0.013973414897918701,...
# 3  [-0.013337471522390842, -0.0008283160859718919...
# 4  [-0.013657728210091591, -0.0007818503072485328...

# %%
def create_context(
    question, df, max_len=1800, size="ada"
):
    """
    Create a context for a question by finding the most similar context from the dataframe
    """

    # Get the embeddings for the question
    q_embeddings = openai.Embedding.create(input=question, engine='text-embedding-ada-002')['data'][0]['embedding']

    # Get the distances from the embeddings
    df['distances'] = distances_from_embeddings(q_embeddings, df['embeddings'].values, distance_metric='cosine')


    returns = []
    cur_len = 0

    # Sort by distance and add the text to the context until the context is too long
    for i, row in df.sort_values('distances', ascending=True).iterrows():
        
        # Add the length of the text to the current length
        cur_len += row['n_tokens'] + 4
        
        # If the context is too long, break
        if cur_len > max_len:
            break
        
        # Else add it to the text that is being returned
        returns.append(row["text"])

    # Return the context
    return "\n\n###\n\n".join(returns)

def answer_question(
    df,
    model="text-davinci-003",
    question="Am I allowed to publish model outputs to Twitter, without a human review?",
    max_len=1800,
    size="ada",
    debug=False,
    max_tokens=1000,
    stop_sequence=None
):
    """
    Answer a question based on the most similar context from the dataframe texts
    """
    context = create_context(
        question,
        df,
        max_len=max_len,
        size=size,
    )
    # If debug, print the raw model response
    if debug:
        print("Context:\n" + context)
        print("\n\n")

    try:
        # Create a completions using the question and context
        response = openai.Completion.create(
            prompt=f"Answer the question based on the context below, and if the question can't be answered based on the context, say \"I don't ajskhdnbknow \"\n\nContext: {context}\n\n---\n\nQuestion: {question}\nAnswer:",
            temperature=0,
            max_tokens=max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=stop_sequence,
            model=model,
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
answer_question(df, question="What day is it?", debug=False)
# Out:
# "I don't know."

# %%
answer_question(df, question="What is our newest embeddings model?")
# Out:
# 'The newest embeddings model is text-embedding-ada-002.'

# %%
answer_question(df, question="Give me a description of what OpenAI does.")
# Out:
# 'OpenAI is a non-profit artificial intelligence research company. Their goal is to advance digital intelligence in a way that is most likely to benefit humanity as a whole, unconstrained by a need to generate financial return. They use deep learning techniques to achieve state-of-the-art results in a wide variety of problem domains, such as recognizing objects in images, machine translation, and speech recognition. They also explore what it might be like for computers to be creative, to dream, and to experience the world.'

# %%
answer_question(df, question="What are some of OpenAI's milestones?")
# Out:
# "OpenAI's milestones include Multimodal Neurons in Artificial Neural Networks (March 4, 2021), DALL·E: Creating Images from Text (January 5, 2021), CLIP: Connecting Text and Images (January 5, 2021), Image GPT (June 17, 2020), Jukebox (April 30, 2020), Solving Rubik’s Cube with a Robot Hand (October 15, 2019), Emergent Tool Use from Multi-Agent Interaction (September 17, 2019), MuseNet (April 25, 2019), Better Language Models and Their Implications (February 14, 2019), How AI Training Scales (December 14, 2018), Learning Dexterity (July 30, 2018), Improving Language Understanding with Unsupervised Learning (June 11, 2018), OpenAI Charter (April 9, 2018), Retro Contest (April 5, 2018), Ingredients for Robotics Research (February 26, 2018), Block-Sparse GPU Kernels (December 6, 2017), Competitive Self-Play (October 11, 2017), OpenAI Baselines: ACKTR & A2C (August 18, 2017), Better Exploration with Parameter Noise (July 27, 2017), Proximal Policy Optimization (July 20, 2017), OpenAI Baselines: DQN (May 24, 2017), Robots that Learn (May 16, 2017), Unsupervised Sentiment Neuron (April 6, 2017), Evolution Strategies as a Scalable Alternative to Reinforcement Learning (March 24, 2017), Generative Models (June 16, 2016)."
